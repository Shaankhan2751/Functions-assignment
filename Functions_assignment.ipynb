# %% [markdown]
# #Functions Assignment

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
#   - a function is a reusable block of code,and it is an independent object that can be directly called itself.<br>
#   e.g def greet(name):
#           print("Welcome back {name}")
#       greet("kamran")
#   - a method is an function that is declared in a class and cant be directly called and has to be assigned to a variable and then called.
#   <br> e.g
#   <br>class Person:<br>
#   def welcome(self,name):<br>
#   print(f"Welcome home {name}")
#   <br>def goodbye(self,name):<br>
#   print(f"Goodbyee see you soon{name}")
#   <br>a=Person("Alice")
#   <br>print(a.welcome()) // Welcome home Alice
#
# 2. Explain the concept of function arguments and parameters in Python.
#
#   - function arguments refers to the variable placeholders declared in the function itself that helps in function codes<br> e.g <br> def add(x,y):
#   <br>   return x+y
#   - function parameters are the provided dataset to process the code in a function
# <br> e.g<br> a=add(5,6)
# <br>print(a) // 11
#
# 3. What are the different ways to define and call a function in Python?
#
#   - There are several ways to define and call a function<br>
#   some of them are <br>
#   1.Direct Declaration<br>
#   def greet(name):<br>
#   &emsp; print("Hello {name}")
#   <br>2.Inside a class
# <br>class person(self):
# <br> def greet(self,name):<br>
# &emsp;print("hello {name}")
#
# 4. What is the purpose of the `return` statement in a Python function?
#
#   - return statement helps in function to return the final product of the function process as it eliminates the need of print statement which might hinder with the expected output.
#   - return statement not only prints the output but it allows us to store and manipulate it to our future needs <br>e.g<br>
#   def add(x,y):<br>
#   &emsp;return x+y
# <br>result=add(6,7)
# <br>print(result*2) // 26
# <br> from the above example we understood that the return function returns back the actual value rather than printing it which is the main use in a function.
#
# 5. What are iterators in Python and how do they differ from iterables?
#
#   - iterables in simple term refers to something that can be iterated over in sequence to produce sub parts of it <br>
#   my_list=[1,2,3,4,5]<br>
#   for i in my_list:<br>
#   &emsp;print(i)
#   - iterators is an facility that can fetch one item from the iterables at a time which can also be called as yield which can be beneficial to extract the data without pressurizing the computer to extract all of the data at once.<br>
#   e.g<br>
#   a=[5,6,7,8]<br>
#   iterator=iter(a)<br>
#   print(next(a)) // 5
#   print(next(a)) // 6
#
# 6. Explain the concept of generators in Python and how they are defined.
#
#   - generators in python is a type of iterator used in a function used along with the yield keyword to extract the data one by one<br>
#   def countdown(n):<br>
#   while n>0:<br>
#   yield n
#   <br> n-=1
#   <br>gen=countdown(5)
#   <br>for num in gen:
#   <br>print(num)<br>
#   all generators are iterators the only difference is that it is used inside a looping function along with the yield and can be extracted using the next keyword from the previous state of the generator.
#
# 7. What are the advantages of using generators over regular functions?
#
#   - generators give more control to the user by only producing the results sequentially by users command saving us time and memory and also making the process alot more efficient.
#   - simpler syntax improves the readability and simplicity of the program.
#
# 8. What is a lambda function in Python and when is it typically used?
#
#   - lambda function is python is a special type of keyword to make a function more concise and specific to an area saving alot of time and making the pprogram memory and space efficient they are called as lambda expressions they can have a series of variables declared.<br>
#   add= lambda x,y:x+y<br>print(add(6,7)) // 13<br>they are often used as a throwaway functions as they dont require specific name declaration so they are used for a specific part of a program as they are also called as anonymous functions.
#
# 9. Explain the purpose and usage of the `map()` function in Python.
#
#   - map function is used to apply a function to a series of iterables in a short and concise manner without needing to write a large function saving time,space and memory and returns a map object it also helps avoid using excessive explicit looping and it is often used with lambda function.
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
#   - map is used to apply a function to a series of iterables avoiding explicit looping and making the code concise,simpler and easy to understand.
#   - reduce keyword is used to apply a function to a series of iterables till reducing it to very last meeting the condition.
#   - filter is keyword is used to apply a certain condition to a series of iterables till they meet the conditions.
#
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];

# %% [markdown]
# ![pw.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #Practical Questions:

# %% [markdown]
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list.

# %%
numbers=[5,8,3,9,4,2,1]
def even_sum(numbers):
  sum=0
  for i in numbers:
    if i%2==0:
      sum+=i
  return sum
print(even_sum(numbers))
# Out:
# 14

# %% [markdown]
# 2. Create a Python function that accepts a string and returns the reverse of that string.

# %%
name="kamran"
def reverse(name):
  return name[::-1]
print(reverse(name))
# Out:
# narmak

# %% [markdown]
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number

# %%
num=[5,6,7,8]
def square(num):
  return [i**2 for i in num]
print(square(num))
# Out:
# [25, 36, 49, 64]

# %% [markdown]
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

# %%
def is_prime(n):
    if n < 1:
        print("Invalid Input")
    elif n>= 1 and n<=200:
        for i in range(2, int(n ** 0.5) + 1):
            if n % i == 0:
                return False
    return True
data=[4,6,8,9,1,56,200,36]
for num in data :
    if is_prime(num):
        print(num, "is a Prime Number")
    else:
        print(num, "is Not a Prime Number")
# Out:
# 4 is Not a Prime Number
# 6 is Not a Prime Number
# 8 is Not a Prime Number
# 9 is Not a Prime Number
# 1 is a Prime Number
# 56 is Not a Prime Number
# 200 is Not a Prime Number
# 36 is Not a Prime Number

# %% [markdown]
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.

# %%
class FibonacciIterator:
    def __init__(self, n):
        self.n, self.a, self.b, self.count = n, 0, 1, 0

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.n:
            raise StopIteration
        self.a, self.b = self.b, self.a + self.b if self.count else self.a
        self.count += 1
        return self.a

n_terms = 10
for num in FibonacciIterator(n_terms):
    print(num)
# Out:
# 1
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %% [markdown]
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

# %%
def powers_of_two(max_exp):
    for exp in range(max_exp + 1):
        yield 2 ** exp

for power in powers_of_two(5):
    print(power, end=" ")
# Out:
# 1 2 4 8 16 32

# %% [markdown]
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

# %%
def read_file_lines(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

file_path = "example.txt"
for line in read_file_lines(file_path):
    print(line)

# %% [markdown]
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

# %%
tuples_list = [(1, 3), (2, 1), (4, 2), (3, 5)]
tuples_list.sort(key=lambda x: x[1])
print(tuples_list)
# Out:
# [(2, 1), (4, 2), (1, 3), (3, 5)]

# %% [markdown]
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

# %%
celsius_temps = [0, 20, 30, 40, 100]
fahrenheit_temps = list(map(lambda c: (c * 9/5) + 32, celsius_temps))
print(fahrenheit_temps)
# Out:
# [32.0, 68.0, 86.0, 104.0, 212.0]

# %% [markdown]
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

# %%
def is_not_vowel(char):
    vowels = 'aeiouAEIOU'
    return char not in vowels

text = "Hello World"
filtered = filter(is_not_vowel, text)
result = ''.join(filtered)

print(result)
# Out:
# Hll Wrld

# %% [markdown]
# 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:![Screenshot 2025-04-03 231257.png](data:image/png;base64,...)
#
#
# Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
# product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
# order is smaller than 100,00 €.
#
# Write a Python program using lambda and map.

# %%
worders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]

result = list(map(lambda order: (order[0], order[2] * order[3] + (10 if order[2] * order[3] < 100 else 0)), orders))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
